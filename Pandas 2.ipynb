# %%
dict 
csv  ->

# %%
types :
    normal file -- text file 
        values comma separated values
    tsv - tab separated values

# %%
text.xlsx
text.pdf



extension :

# %%
we fetch -- data -- dataframe

# %%
web crawling : web scrapping : 
        
        
        
        python -- web site --> scrap

# %%
import pandas as pd

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/COVID-19_pandemic_by_country_and_territory')

# %%
df[12]
# Out:
#                                             Unnamed: 0  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
# 238                                                NaN
# 239  .mw-parser-output .reflist{font-size:90%;margi...
#
#                                                Country  \
# 0                                             World[a]
# 1                                                 Peru
# 2                                             Bulgaria
# 3                               Bosnia and Herzegovina
# ...

# %%
5.Dataframe using api

# %%
df2 = pd.read_json('https://dummyjson.com/products')

# %%
df2['products']
# Out:
# 0     {'id': 1, 'title': 'iPhone 9', 'description': ...
# 1     {'id': 2, 'title': 'iPhone X', 'description': ...
# 2     {'id': 3, 'title': 'Samsung Universe 9', 'desc...
# 3     {'id': 4, 'title': 'OPPOF19', 'description': '...
# 4     {'id': 5, 'title': 'Huawei P30', 'description'...
# 5     {'id': 6, 'title': 'MacBook Pro', 'description...
# 6     {'id': 7, 'title': 'Samsung Galaxy Book', 'des...
# 7     {'id': 8, 'title': 'Microsoft Surface Laptop 4...
# 8     {'id': 9, 'title': 'Infinix INBOOK', 'descript...
# 9     {'id': 10, 'title': 'HP Pavilion 15-DK1056WM',...
# 10    {'id': 11, 'title': 'perfume Oil', 'descriptio...
# 11    {'id': 12, 'title': 'Brown Perfume', 'descript...
# 12    {'id': 13, 'title': 'Fog Scent Xpressio Perfum...
# 13    {'id': 14, 'title': 'Non-Alcoholic Concentrate...
# 14    {'id': 15, 'title': 'Eau De Perfume Spray', 'd...
# 15    {'id': 16, 'title': 'Hyaluronic Acid Serum', '...
# 16    {'id': 17, 'title': 'Tree Oil 30ml', 'descript...
# ...

# %%
df4 = pd.read_json('https://dummy.restapiexample.com/api/v1/employees')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 df4 = pd.read_json('https://dummy.restapiexample.com/api/v1/employees')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_csv('Amazon_Car_Accessories - Amazon_Car_Accessories.csv')

# %%
df
# Out:
#                                                   Title Price Number reviews  \
# 0     Dorman 955-167 Driver Side Power Door Mirror f...    35            101
# 1     CURT 51323 Quick Plug Electric Trailer Brake C...    19            386
# 2     HAMPTON PROD Keeper - 48” Carabiner Bungee Cor...    13          1,573
# 3     CR Brophy Machine Works RB34 1" x 3/4" Hitch B...     2              9
# 4     Ampper Blind Spot Mirror, 2" Round HD Glass Fr...     8         20,378
# ...                                                 ...   ...            ...
# 9568                   Warn 74924 (MTO) DRUM_WINCH_RT40    76             11
# 9569  Rugged Ridge 11580.10 Trailer Hitch, 2 inch; 0...     7              5
# 9570            Gates 31633 OE Equivalent Fuel Tank Cap    71              5
# 9571  BIG RED 2.5 Ton (5000 lb) Torin Low Profile Hy...    35              5
# 9572  BIG RED ATRT2272CR Torin Manual Heavy Duty Han...    26              5
#
# ...

# %%
df.shape
# Out:
# (9573, 9)

# %%
df.columns
# Out:
# Index(['Title', 'Price', 'Number reviews', 'Real price', 'Free days',
#        'Shipment', 'Delivery Date', 'How many time in past month',
#        'Stock update'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Title                          object
# Price                          object
# Number reviews                 object
# Real price                     object
# Free days                      object
# Shipment                       object
# Delivery Date                  object
# How many time in past month    object
# Stock update                   object
# dtype: object

# %%
python   char/str --string

pandas --char/str -->object

# %%
email --> file - sharepoint  --> database -- api

# %%
df
# Out:
#                                                   Title Price Number reviews  \
# 0     Dorman 955-167 Driver Side Power Door Mirror f...    35            101
# 1     CURT 51323 Quick Plug Electric Trailer Brake C...    19            386
# 2     HAMPTON PROD Keeper - 48” Carabiner Bungee Cor...    13          1,573
# 3     CR Brophy Machine Works RB34 1" x 3/4" Hitch B...     2              9
# 4     Ampper Blind Spot Mirror, 2" Round HD Glass Fr...     8         20,378
# ...                                                 ...   ...            ...
# 9568                   Warn 74924 (MTO) DRUM_WINCH_RT40    76             11
# 9569  Rugged Ridge 11580.10 Trailer Hitch, 2 inch; 0...     7              5
# 9570            Gates 31633 OE Equivalent Fuel Tank Cap    71              5
# 9571  BIG RED 2.5 Ton (5000 lb) Torin Low Profile Hy...    35              5
# 9572  BIG RED ATRT2272CR Torin Manual Heavy Duty Han...    26              5
#
# ...

# %%
df
# Out:
#                                                   Title Price Number reviews  \
# 0     Dorman 955-167 Driver Side Power Door Mirror f...    35            101
# 1     CURT 51323 Quick Plug Electric Trailer Brake C...    19            386
# 2     HAMPTON PROD Keeper - 48” Carabiner Bungee Cor...    13          1,573
# 3     CR Brophy Machine Works RB34 1" x 3/4" Hitch B...     2              9
# 4     Ampper Blind Spot Mirror, 2" Round HD Glass Fr...     8         20,378
# ...                                                 ...   ...            ...
# 9568                   Warn 74924 (MTO) DRUM_WINCH_RT40    76             11
# 9569  Rugged Ridge 11580.10 Trailer Hitch, 2 inch; 0...     7              5
# 9570            Gates 31633 OE Equivalent Fuel Tank Cap    71              5
# 9571  BIG RED 2.5 Ton (5000 lb) Torin Low Profile Hy...    35              5
# 9572  BIG RED ATRT2272CR Torin Manual Heavy Duty Han...    26              5
#
# ...

# %%
df['Price']
# Out:
# 0       35
# 1       19
# 2       13
# 3        2
# 4        8
#         ..
# 9568    76
# 9569     7
# 9570    71
# 9571    35
# 9572    26
# Name: Price, Length: 9573, dtype: object

# %%
df.Price
# Out:
# 0       35
# 1       19
# 2       13
# 3        2
# 4        8
#         ..
# 9568    76
# 9569     7
# 9570    71
# 9571    35
# 9572    26
# Name: Price, Length: 9573, dtype: object

# %%
col name --no space  -- both method

col name -- if space -->

# %%
df.Number reviews
# Out:
#   Input In [35]
#     df.Number reviews
#               ^
# SyntaxError: invalid syntax

# %%
df['Number reviews']
# Out:
# 0          101
# 1          386
# 2        1,573
# 3            9
# 4       20,378
#          ...
# 9568        11
# 9569         5
# 9570         5
# 9571         5
# 9572         5
# Name: Number reviews, Length: 9573, dtype: object

# %%
df1= df[['Title','Price','Shipment']]

# %%
df1.to_csv('test.csv')

# %%
df1.to_excel('test.xlsx',index=False)

# %%
df1.to_html(r'C:\Users\kanti\OneDrive\Desktop\mypythonproject\test.html')

# %%
df
# Out:
#                                                   Title Price Number reviews  \
# 0     Dorman 955-167 Driver Side Power Door Mirror f...    35            101
# 1     CURT 51323 Quick Plug Electric Trailer Brake C...    19            386
# 2     HAMPTON PROD Keeper - 48” Carabiner Bungee Cor...    13          1,573
# 3     CR Brophy Machine Works RB34 1" x 3/4" Hitch B...     2              9
# 4     Ampper Blind Spot Mirror, 2" Round HD Glass Fr...     8         20,378
# ...                                                 ...   ...            ...
# 9568                   Warn 74924 (MTO) DRUM_WINCH_RT40    76             11
# 9569  Rugged Ridge 11580.10 Trailer Hitch, 2 inch; 0...     7              5
# 9570            Gates 31633 OE Equivalent Fuel Tank Cap    71              5
# 9571  BIG RED 2.5 Ton (5000 lb) Torin Low Profile Hy...    35              5
# 9572  BIG RED ATRT2272CR Torin Manual Heavy Duty Han...    26              5
#
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Price', 'Number reviews', 'Real price', 'Free days',
#        'Shipment', 'Delivery Date', 'How many time in past month',
#        'Stock update'],
#       dtype='object')

# %%
manually --> time

# %%
cols = []
for col in df.columns:
    if col not in ['Free days','Price','Title']:
        cols.append(col)

# %%
cols
# Out:
# ['Number reviews',
#  'Real price',
#  'Shipment',
#  'Delivery Date',
#  'How many time in past month',
#  'Stock update']

# %%
df[cols]
# Out:
#      Number reviews Real price Shipment Delivery Date  \
# 0               101      $1.92      Yes   Mon, Jun 19
# 1               386      $1.93      Yes   Mon, Jun 19
# 2             1,573      $2.90      Yes   Mon, Jun 19
# 3                 9      $2.90      Yes   Mon, Jun 19
# 4            20,378      $3.14      Yes   Mon, Jun 19
# ...             ...        ...      ...           ...
# 9568             11       None      Yes   Mon, Jun 19
# 9569              5       None      Yes   Mon, Jun 19
# 9570              5       None      Yes   Mon, Jun 19
# 9571              5       None      Yes   Mon, Jun 19
# 9572              5       None      Yes   Mon, Jun 19
#
#      How many time in past month                              Stock update
# 0        50+ bought in past week        Only 7 left in stock - order soon.
# 1        50+ bought in past week   Only 4 left in stock (more on the way).
# 2        50+ bought in past week  Only 16 left in stock (more on the way).
# ...

# %%
100 -- 5  --> python code

# %%
df3 = df[[col for col in df.columns  if col not in ['Free days','Price','Title']]]

# %%
df -- new col add

# %%
df
# Out:
#                                                   Title Price Number reviews  \
# 0     Dorman 955-167 Driver Side Power Door Mirror f...    35            101
# 1     CURT 51323 Quick Plug Electric Trailer Brake C...    19            386
# 2     HAMPTON PROD Keeper - 48” Carabiner Bungee Cor...    13          1,573
# 3     CR Brophy Machine Works RB34 1" x 3/4" Hitch B...     2              9
# 4     Ampper Blind Spot Mirror, 2" Round HD Glass Fr...     8         20,378
# ...                                                 ...   ...            ...
# 9568                   Warn 74924 (MTO) DRUM_WINCH_RT40    76             11
# 9569  Rugged Ridge 11580.10 Trailer Hitch, 2 inch; 0...     7              5
# 9570            Gates 31633 OE Equivalent Fuel Tank Cap    71              5
# 9571  BIG RED 2.5 Ton (5000 lb) Torin Low Profile Hy...    35              5
# 9572  BIG RED ATRT2272CR Torin Manual Heavy Duty Han...    26              5
#
# ...

# %%
df3['test'] = df['Number reviews']*2
# Out:
# C:\Users\kanti\AppData\Local\Temp\ipykernel_10328\4272261182.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['test'] = df['Number reviews']*2

# %%
df3
# Out:
#      Number reviews Real price Shipment Delivery Date  \
# 0               101      $1.92      Yes   Mon, Jun 19
# 1               386      $1.93      Yes   Mon, Jun 19
# 2             1,573      $2.90      Yes   Mon, Jun 19
# 3                 9      $2.90      Yes   Mon, Jun 19
# 4            20,378      $3.14      Yes   Mon, Jun 19
# ...             ...        ...      ...           ...
# 9568             11       None      Yes   Mon, Jun 19
# 9569              5       None      Yes   Mon, Jun 19
# 9570              5       None      Yes   Mon, Jun 19
# 9571              5       None      Yes   Mon, Jun 19
# 9572              5       None      Yes   Mon, Jun 19
#
#      How many time in past month                              Stock update  \
# 0        50+ bought in past week        Only 7 left in stock - order soon.
# 1        50+ bought in past week   Only 4 left in stock (more on the way).
# 2        50+ bought in past week  Only 16 left in stock (more on the way).
# ...

# %%
df3['lenofStock update'] =  len(df3['Stock update'])
# Out:
# C:\Users\kanti\AppData\Local\Temp\ipykernel_10328\2810776397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['lenofStock update'] =  len(df3['Stock update'])

# %%
df3
# Out:
#      Number reviews Real price Shipment Delivery Date  \
# 0               101      $1.92      Yes   Mon, Jun 19
# 1               386      $1.93      Yes   Mon, Jun 19
# 2             1,573      $2.90      Yes   Mon, Jun 19
# 3                 9      $2.90      Yes   Mon, Jun 19
# 4            20,378      $3.14      Yes   Mon, Jun 19
# ...             ...        ...      ...           ...
# 9568             11       None      Yes   Mon, Jun 19
# 9569              5       None      Yes   Mon, Jun 19
# 9570              5       None      Yes   Mon, Jun 19
# 9571              5       None      Yes   Mon, Jun 19
# 9572              5       None      Yes   Mon, Jun 19
#
#      How many time in past month                              Stock update  \
# 0        50+ bought in past week        Only 7 left in stock - order soon.
# 1        50+ bought in past week   Only 4 left in stock (more on the way).
# 2        50+ bought in past week  Only 16 left in stock (more on the way).
# ...

# %%
df['Stock update']
# Out:
# 0             Only 7 left in stock - order soon.
# 1        Only 4 left in stock (more on the way).
# 2       Only 16 left in stock (more on the way).
# 3             Only 3 left in stock - order soon.
# 4             Only 2 left in stock - order soon.
#                           ...
# 9568    Only 17 left in stock (more on the way).
# 9569    Only 17 left in stock (more on the way).
# 9570    Only 17 left in stock (more on the way).
# 9571    Only 17 left in stock (more on the way).
# 9572    Only 17 left in stock (more on the way).
# Name: Stock update, Length: 9573, dtype: object

# %%
len(df3['Stock update'])
# Out:
# 9573

# %%
len('Only 7 left in stock - order soon.')
# Out:
# 34

# %%
df3['newcolname'] = 'asdfsadf'

# %%
df3
# Out:
#      Number reviews Real price Shipment Delivery Date  \
# 0               101      $1.92      Yes   Mon, Jun 19
# 1               386      $1.93      Yes   Mon, Jun 19
# 2             1,573      $2.90      Yes   Mon, Jun 19
# 3                 9      $2.90      Yes   Mon, Jun 19
# 4            20,378      $3.14      Yes   Mon, Jun 19
# ...             ...        ...      ...           ...
# 9568             11       None      Yes   Mon, Jun 19
# 9569              5       None      Yes   Mon, Jun 19
# 9570              5       None      Yes   Mon, Jun 19
# 9571              5       None      Yes   Mon, Jun 19
# 9572              5       None      Yes   Mon, Jun 19
#
#      How many time in past month                              Stock update  \
# 0        50+ bought in past week        Only 7 left in stock - order soon.
# 1        50+ bought in past week   Only 4 left in stock (more on the way).
# 2        50+ bought in past week  Only 16 left in stock (more on the way).
# ...

# %%
col -- delete from dataframe

# %%
df4 = df3.drop('test',axis=1)

# %%
axis -->

# %%
df4
# Out:
#      Number reviews Real price Shipment Delivery Date  \
# 0               101      $1.92      Yes   Mon, Jun 19
# 1               386      $1.93      Yes   Mon, Jun 19
# 2             1,573      $2.90      Yes   Mon, Jun 19
# 3                 9      $2.90      Yes   Mon, Jun 19
# 4            20,378      $3.14      Yes   Mon, Jun 19
# ...             ...        ...      ...           ...
# 9568             11       None      Yes   Mon, Jun 19
# 9569              5       None      Yes   Mon, Jun 19
# 9570              5       None      Yes   Mon, Jun 19
# 9571              5       None      Yes   Mon, Jun 19
# 9572              5       None      Yes   Mon, Jun 19
#
#      How many time in past month                              Stock update  \
# 0        50+ bought in past week        Only 7 left in stock - order soon.
# 1        50+ bought in past week   Only 4 left in stock (more on the way).
# 2        50+ bought in past week  Only 16 left in stock (more on the way).
# ...

# %%
df3.drop('test',axis=1,inplace=True)

# %%
df3
# Out:
#      Number reviews Real price Shipment Delivery Date  \
# 0               101      $1.92      Yes   Mon, Jun 19
# 1               386      $1.93      Yes   Mon, Jun 19
# 2             1,573      $2.90      Yes   Mon, Jun 19
# 3                 9      $2.90      Yes   Mon, Jun 19
# 4            20,378      $3.14      Yes   Mon, Jun 19
# ...             ...        ...      ...           ...
# 9568             11       None      Yes   Mon, Jun 19
# 9569              5       None      Yes   Mon, Jun 19
# 9570              5       None      Yes   Mon, Jun 19
# 9571              5       None      Yes   Mon, Jun 19
# 9572              5       None      Yes   Mon, Jun 19
#
#      How many time in past month                              Stock update  \
# 0        50+ bought in past week        Only 7 left in stock - order soon.
# 1        50+ bought in past week   Only 4 left in stock (more on the way).
# 2        50+ bought in past week  Only 16 left in stock (more on the way).
# ...

# %%
df3.drop(columns=['lenofStock update','len_temp','newcolname'],axis=1,inplace=True)

# %%
df3
# Out:
#      Number reviews Real price Shipment Delivery Date  \
# 0               101      $1.92      Yes   Mon, Jun 19
# 1               386      $1.93      Yes   Mon, Jun 19
# 2             1,573      $2.90      Yes   Mon, Jun 19
# 3                 9      $2.90      Yes   Mon, Jun 19
# 4            20,378      $3.14      Yes   Mon, Jun 19
# ...             ...        ...      ...           ...
# 9568             11       None      Yes   Mon, Jun 19
# 9569              5       None      Yes   Mon, Jun 19
# 9570              5       None      Yes   Mon, Jun 19
# 9571              5       None      Yes   Mon, Jun 19
# 9572              5       None      Yes   Mon, Jun 19
#
#      How many time in past month                              Stock update
# 0        50+ bought in past week        Only 7 left in stock - order soon.
# 1        50+ bought in past week   Only 4 left in stock (more on the way).
# 2        50+ bought in past week  Only 16 left in stock (more on the way).
# ...

# %%
cols = []
for col in df3.columns:
    if col not in ['Real price','Delivery Date','Stock update']:
        cols.append(col)

# %%
cols
# Out:
# ['Number reviews', 'Shipment', 'How many time in past month']

# %%
df3.drop(columns=cols,axis=1,inplace=True)

# %%
df3
# Out:
#      Real price Delivery Date                              Stock update
# 0         $1.92   Mon, Jun 19        Only 7 left in stock - order soon.
# 1         $1.93   Mon, Jun 19   Only 4 left in stock (more on the way).
# 2         $2.90   Mon, Jun 19  Only 16 left in stock (more on the way).
# 3         $2.90   Mon, Jun 19        Only 3 left in stock - order soon.
# 4         $3.14   Mon, Jun 19        Only 2 left in stock - order soon.
# ...         ...           ...                                       ...
# 9568       None   Mon, Jun 19  Only 17 left in stock (more on the way).
# 9569       None   Mon, Jun 19  Only 17 left in stock (more on the way).
# 9570       None   Mon, Jun 19  Only 17 left in stock (more on the way).
# 9571       None   Mon, Jun 19  Only 17 left in stock (more on the way).
# 9572       None   Mon, Jun 19  Only 17 left in stock (more on the way).
#
# [9573 rows x 3 columns]

# %%
df
# Out:
#                                                   Title Price Number reviews  \
# 0     Dorman 955-167 Driver Side Power Door Mirror f...    35            101
# 1     CURT 51323 Quick Plug Electric Trailer Brake C...    19            386
# 2     HAMPTON PROD Keeper - 48” Carabiner Bungee Cor...    13          1,573
# 3     CR Brophy Machine Works RB34 1" x 3/4" Hitch B...     2              9
# 4     Ampper Blind Spot Mirror, 2" Round HD Glass Fr...     8         20,378
# ...                                                 ...   ...            ...
# 9568                   Warn 74924 (MTO) DRUM_WINCH_RT40    76             11
# 9569  Rugged Ridge 11580.10 Trailer Hitch, 2 inch; 0...     7              5
# 9570            Gates 31633 OE Equivalent Fuel Tank Cap    71              5
# 9571  BIG RED 2.5 Ton (5000 lb) Torin Low Profile Hy...    35              5
# 9572  BIG RED ATRT2272CR Torin Manual Heavy Duty Han...    26              5
#
# ...
